# %%
import matplotlib.pyplot as plt

# %%
data = [x.strip().split(',') for x in open('in').readlines()]
data = [(int(x[0]),int(x[1])) for x in data]
x = [x[0] for x in data]
y = [x[1] for x in data]
p1, p2, p3, p4 = (41937, 3086,41937, 2138)
k,l,z,j = (2146, 53300,85290, 17789)

# %%
plt.plot(x,y)
plt.plot(p1,p2,'r*')
plt.plot(p3,p4,'r*')
plt.plot(k,l,'g+')
plt.plot(z,j,'g+')
